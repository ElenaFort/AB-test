# %%
from IPython.display import Image

display(Image(filename='1.png'))

# %% [markdown]
# **Создание контейнера и проекта оптимизации**

# %%
display(Image(filename='2.png'))

# %% [markdown]
# **Сократила текст в левой части экрана и стиль изменила на курсив. Стиль написания привлекает внимание, а короткий текст быстрее читается. Значит больше шансов, что гость обратит на него внимание и дочитает до конца. Т.о. можно увеличить количество новых пользователей на Х %**

# %%
display(Image(filename='3.png'))

# %% [markdown]
# **Получилось 2 изменения**

# %%
display(Image(filename='4.png'))

# %% [markdown]
# **Добавила целевую аудиторию и описание**

# %%
display(Image(filename='5.png'))
display(Image(filename='6.png'))

# %% [markdown]
# **Создала аккаунт Google Аналитика и установила связь**

# %%
display(Image(filename='7.png'))

# %% [markdown]
# **Добавила цель**

# %%
display(Image(filename='8.png'))

# %% [markdown]
# **Запуск**

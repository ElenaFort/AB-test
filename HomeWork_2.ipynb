# %% [markdown]
# <a href="https://colab.research.google.com/github/ElenaFort/AB-test/blob/main/HomeWork_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Урок 2. А/Б тестирование
#
# ## Задание 1: Сделайте приоритезацию гипотез из предыдущего урока с помощью ICE
#
# **Гипотеза 1:** (Добавить больше магазинов - партнёров)
#
# *IMPACT* - полезность внедрения: 7
#
# *CONFIDENCE* - уверенность:      1
#
# *EASY* - лёгкость реализации:    8
#
# ICE: 56
#
# **Гипотеза 2:** (Сделать корзину заметней)
#
# *IMPACT* - полезность внедрения: 8
#
# *CONFIDENCE* - уверенность:      3
#
# *EASY* - лёгкость реализации:    9
#
# ICE: 216
#
# **Гипотеза 3:** (Увеличить количество сборщиков и курьеров)
#
# *IMPACT* - полезность внедрения: 6
#
# *CONFIDENCE* - уверенность:      1
#
# *EASY* - лёгкость реализации:    8
#
# ICE: 48

# %% [markdown]
# ## Задание 2. Составьте шаблон дизайна эксперимента для гипотезы, которая набрала больше всего баллов в практическом задании предыдущего урока
#
# 1. **Гипотеза:**
#
#  Можно увеличить количество первых покупок на Х%, если сделать иконку корзины на всех страницах заметней (больше + контрастней цвет), потому что клиент сможет чаще обращать внимание на кнопку корзины.
#
# 2. **Что делаем:**
# - Контрольная версия: оставляем всё как было.
# - Тестовая версия: делаем корзину более заметной, как описано в гипотезе.
#
# 3. **На каких пользователях тестируем:** На новых пользователях.
#
# 4. **Ключевые метрики:**
# - количество покупок, сделанных новыми пользователями
# - количество повторных заказов
#
# 5. **Ожидаемый эффект:**
#
#  Увеличение количества заказов
#
# 6. **План действий:**
#
# - Если результат эксперимента будет положительным и прирост значений
# ключевых метрик будет не менее ожидаемого, то распространяем изменения на всех
# пользователей.
# - Если значения ключевых метрик снижаются или имеют незначительный
# прирост, то откатываем эксперимент.

# %% [markdown]
# # Урок 4. A/B-тестирование мобильных приложений
#
# ## Настроить а/б тест на сайте с 2-мя изменениями

# %%
from IPython.display import Image

display(Image(filename='1.png'))

# %% [markdown]
# **Начало**

# %% [markdown]
# ## Notification

# %%
display(Image(filename='2.png'))
display(Image(filename='3.png'))
display(Image(filename='4.png'))

# %% [markdown]
# ## Remote config

# %%
display(Image(filename='5.png'))
display(Image(filename='6.png'))
display(Image(filename='7.png'))

# %% [markdown]
# ## In-App Messaging

# %%
display(Image(filename='8.png'))
display(Image(filename='9.png'))
display(Image(filename='10.png'))
display(Image(filename='11.png'))
display(Image(filename='12.png'))
display(Image(filename='13.png'))

# %% [markdown]
# **Все тесты:**

# %%
display(Image(filename='14.png'))
